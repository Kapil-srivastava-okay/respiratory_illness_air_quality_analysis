# %%
import pandas as pd
import numpy as np

# Read the dataset
path = 'air_quality_pollutants_combined_dataset.csv'
df = pd.read_csv(path)
df.head()
# Out:
# C:\Users\kapil\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#          date  acute_bronchiolitis_syndromic  acute_respiratory_illness  \
# 0  09-06-2024                            2.0                      176.0
# 1  10-06-2024                            7.0                      166.0
# 2  11-06-2024                            6.0                      155.0
# 3  12-06-2024                            2.0                      157.0
# 4  13-06-2024                            3.0                      137.0
#
#    influenza_like_syndromic  scarlet_fever_syndromic  black_carbon  \
# 0                       2.0                      3.0         0.403
# 1                       2.0                      0.0         0.337
# 2                       0.0                      0.0         0.480
# 3                       0.0                      0.0         0.663
# 4                       0.0                      0.0         0.667
#
#    blue_particulate_matter  green_particulate_matter  \
# 0                    0.470                     0.447
# 1                    0.373                     0.353
# 2                    0.530                     0.507
# 3                    0.753                     0.717
# 4                    0.733                     0.703
#
#    infra_red_particulate_matter  nitric_dioxide  nitric_oxide  \
# 0                         0.423           8.000         3.786
# 1                         0.347           8.500         4.214
# 2                         0.487          12.143         5.214
# 3                         0.680          14.500         6.000
# 4                         0.670          13.929         7.643
#
#    nitrogen_oxides_as_nitrogen_dioxide   Ozone  PM10  PM2.5  \
# 0                               13.571  59.444   8.2  4.125
# 1                               14.929  60.900   6.1  3.000
# 2                               19.929  60.500   8.7  4.250
# 3                               23.786  64.500  10.3  4.875
# 4                               25.500  59.300  10.4  4.625
#
#    red_particulate_matter  UV_particulate_matter_370nm  \
# 0                   0.410                        0.467
# 1                   0.327                        0.363
# 2                   0.480                        0.517
# 3                   0.670                        0.747
# 4                   0.670                        0.710
#
#    yellow_particulate_matter_590nm
# 0                            0.430
# 1                            0.347
# 2                            0.503
# 3                            0.703
# 4                            0.693

# %%
# Summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 365 non-null    object
#  1   acute_bronchiolitis_syndromic        365 non-null    float64
#  2   acute_respiratory_illness            365 non-null    float64
#  3   influenza_like_syndromic             365 non-null    float64
#  4   scarlet_fever_syndromic              365 non-null    float64
#  5   black_carbon                         365 non-null    float64
#  6   blue_particulate_matter              365 non-null    float64
#  7   green_particulate_matter             365 non-null    float64
#  8   infra_red_particulate_matter         365 non-null    float64
#  9   nitric_dioxide                       365 non-null    float64
#  10  nitric_oxide                         365 non-null    float64
#  11  nitrogen_oxides_as_nitrogen_dioxide  365 non-null    float64
#  12  Ozone                                365 non-null    float64
#  13  PM10                                 365 non-null    float64
#  14  PM2.5                                365 non-null    float64
#  15  red_particulate_matter               365 non-null    float64
#  16  UV_particulate_matter_370nm          365 non-null    float64
#  17  yellow_particulate_matter_590nm      365 non-null    float64
# dtypes: float64(17), object(1)
# memory usage: 51.5+ KB

# %%
# Descriptive statistics of the dataset
df.describe()
# Out:
#        acute_bronchiolitis_syndromic  acute_respiratory_illness  \
# count                     365.000000                 365.000000
# mean                       14.452055                 214.441096
# std                        12.263859                  73.716937
# min                         1.000000                 105.000000
# 25%                         6.000000                 159.000000
# 50%                        11.000000                 204.000000
# 75%                        16.000000                 245.000000
# max                        65.000000                 470.000000
#
#        influenza_like_syndromic  scarlet_fever_syndromic  black_carbon  \
# count                365.000000               365.000000    365.000000
# mean                  10.863014                 0.504110      0.938573
# std                   15.764854                 0.803912      0.652608
# min                    0.000000                 0.000000      0.150000
# 25%                    1.000000                 0.000000      0.545000
# 50%                    3.000000                 0.000000      0.765000
# 75%                   15.000000                 1.000000      1.120000
# max                   83.000000                 4.000000      5.480000
#
#        blue_particulate_matter  green_particulate_matter  \
# count               365.000000                365.000000
# mean                  1.111288                  1.036507
# std                   0.786021                  0.736182
# min                   0.200000                  0.170000
# 25%                   0.643000                  0.590000
# 50%                   0.900000                  0.833000
# 75%                   1.327000                  1.255000
# max                   6.560000                  6.090000
#
#        infra_red_particulate_matter  nitric_dioxide  nitric_oxide  \
# count                    365.000000      365.000000    365.000000
# mean                       0.961858       17.358408      8.160052
# std                        0.675696        8.448366      8.777164
# min                        0.153000        4.438000      1.333000
# 25%                        0.550000       11.250000      4.312000
# 50%                        0.777000       15.533000      5.800000
# 75%                        1.137000       21.312000      8.188000
# max                        5.600000       57.062000     88.250000
#
#        nitrogen_oxides_as_nitrogen_dioxide       Ozone        PM10  \
# count                           365.000000  365.000000  365.000000
# mean                             29.854948   50.592627   13.827742
# std                              20.827134   16.994278    7.894432
# min                               7.938000    4.273000    2.500000
# 25%                              18.071000   40.455000    8.600000
# 50%                              24.000000   51.818000   11.400000
# 75%                              34.400000   61.727000   17.143000
# max                             192.312000   96.364000   55.333000
#
#             PM2.5  red_particulate_matter  UV_particulate_matter_370nm  \
# count  365.000000              365.000000                   365.000000
# mean     8.384356                0.963712                     1.139074
# std      6.267415                0.675462                     0.839571
# min      1.385000                0.155000                     0.190000
# 25%      4.308000                0.555000                     0.640000
# 50%      6.071000                0.780000                     0.897000
# 75%     10.333000                1.157000                     1.337000
# max     45.154000                5.650000                     6.780000
#
#        yellow_particulate_matter_590nm
# count                       365.000000
# mean                          1.008679
# std                           0.711451
# min                           0.165000
# 25%                           0.580000
# 50%                           0.813000
# 75%                           1.215000
# max                           5.930000

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime

# Set style for better visualizations
plt.style.use('seaborn-v0_8') 
sns.set_palette("deep")

df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')

# 2. Basic Data Overview
print("=== Dataset Overview ===")
print(f"Shape: {df.shape}")
print("\nColumns:", df.columns.tolist())
print("\nMissing Values:\n", df.isnull().sum())
print("\nBasic Statistics:\n", df.describe())
# Out:
# === Dataset Overview ===
# Shape: (365, 18)
#
# Columns: ['date', 'acute_bronchiolitis_syndromic', 'acute_respiratory_illness', 'influenza_like_syndromic', 'scarlet_fever_syndromic', 'black_carbon', 'blue_particulate_matter', 'green_particulate_matter', 'infra_red_particulate_matter', 'nitric_dioxide', 'nitric_oxide', 'nitrogen_oxides_as_nitrogen_dioxide', 'Ozone', 'PM10', 'PM2.5', 'red_particulate_matter', 'UV_particulate_matter_370nm', 'yellow_particulate_matter_590nm']
#
# Missing Values:
#  date                                   0
# acute_bronchiolitis_syndromic          0
# acute_respiratory_illness              0
# influenza_like_syndromic               0
# scarlet_fever_syndromic                0
# black_carbon                           0
# blue_particulate_matter                0
# green_particulate_matter               0
# infra_red_particulate_matter           0
# nitric_dioxide                         0
# nitric_oxide                           0
# nitrogen_oxides_as_nitrogen_dioxide    0
# Ozone                                  0
# PM10                                   0
# PM2.5                                  0
# red_particulate_matter                 0
# UV_particulate_matter_370nm            0
# yellow_particulate_matter_590nm        0
# dtype: int64
#
# Basic Statistics:
#                                  date  acute_bronchiolitis_syndromic  \
# count                            365                     365.000000
# mean   2024-12-08 00:00:00.000000256                      14.452055
# min              2024-06-09 00:00:00                       1.000000
# 25%              2024-09-08 00:00:00                       6.000000
# 50%              2024-12-08 00:00:00                      11.000000
# 75%              2025-03-09 00:00:00                      16.000000
# max              2025-06-08 00:00:00                      65.000000
# std                              NaN                      12.263859
#
#        acute_respiratory_illness  influenza_like_syndromic  \
# count                 365.000000                365.000000
# mean                  214.441096                 10.863014
# min                   105.000000                  0.000000
# 25%                   159.000000                  1.000000
# 50%                   204.000000                  3.000000
# 75%                   245.000000                 15.000000
# max                   470.000000                 83.000000
# std                    73.716937                 15.764854
#
#        scarlet_fever_syndromic  black_carbon  blue_particulate_matter  \
# count               365.000000    365.000000               365.000000
# mean                  0.504110      0.938573                 1.111288
# min                   0.000000      0.150000                 0.200000
# 25%                   0.000000      0.545000                 0.643000
# 50%                   0.000000      0.765000                 0.900000
# 75%                   1.000000      1.120000                 1.327000
# max                   4.000000      5.480000                 6.560000
# std                   0.803912      0.652608                 0.786021
#
#        green_particulate_matter  infra_red_particulate_matter  nitric_dioxide  \
# count                365.000000                    365.000000      365.000000
# mean                   1.036507                      0.961858       17.358408
# min                    0.170000                      0.153000        4.438000
# 25%                    0.590000                      0.550000       11.250000
# 50%                    0.833000                      0.777000       15.533000
# 75%                    1.255000                      1.137000       21.312000
# max                    6.090000                      5.600000       57.062000
# std                    0.736182                      0.675696        8.448366
#
#        nitric_oxide  nitrogen_oxides_as_nitrogen_dioxide       Ozone  \
# count    365.000000                           365.000000  365.000000
# mean       8.160052                            29.854948   50.592627
# min        1.333000                             7.938000    4.273000
# 25%        4.312000                            18.071000   40.455000
# 50%        5.800000                            24.000000   51.818000
# 75%        8.188000                            34.400000   61.727000
# max       88.250000                           192.312000   96.364000
# std        8.777164                            20.827134   16.994278
#
#              PM10       PM2.5  red_particulate_matter  \
# count  365.000000  365.000000              365.000000
# mean    13.827742    8.384356                0.963712
# min      2.500000    1.385000                0.155000
# 25%      8.600000    4.308000                0.555000
# 50%     11.400000    6.071000                0.780000
# 75%     17.143000   10.333000                1.157000
# max     55.333000   45.154000                5.650000
# std      7.894432    6.267415                0.675462
#
#        UV_particulate_matter_370nm  yellow_particulate_matter_590nm
# count                   365.000000                       365.000000
# mean                      1.139074                         1.008679
# min                       0.190000                         0.165000
# 25%                       0.640000                         0.580000
# 50%                       0.897000                         0.813000
# 75%                       1.337000                         1.215000
# max                       6.780000                         5.930000
# std                       0.839571                         0.711451

# %%
# 3. Define health and pollutant columns for analysis
health_columns = ['acute_bronchiolitis_syndromic', 'acute_respiratory_illness', 
                 'influenza_like_syndromic', 'scarlet_fever_syndromic']
pollutant_columns = ['black_carbon', 'blue_particulate_matter', 'green_particulate_matter', 
                     'infra_red_particulate_matter', 'nitric_dioxide', 'nitric_oxide', 
                     'nitrogen_oxides_as_nitrogen_dioxide', 'Ozone', 'PM10', 'PM2.5', 
                     'red_particulate_matter', 'UV_particulate_matter_370nm', 
                     'yellow_particulate_matter_590nm']

# %%
# 4. Time Series Plots for Health Indicators
import matplotlib.dates as mdates
plt.figure(figsize=(12, 6))

# Plot with clearer lines and smaller markers
for col in health_columns:
    plt.plot(df['date'], df[col], label=col, marker='*', markersize=2, linewidth=1.2)

# Title and labels
plt.title('Time Series of Health Indicators')
plt.xlabel('Date')
plt.ylabel('Cases')

# Legend with larger font
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)

# More date ticks
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.DayLocator(interval=30))  # Adjust interval as needed
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
plt.xticks(rotation=45, fontsize=8)

# Layout adjustments
plt.tight_layout()
plt.show()

# %%
# 6. Correlation Matrix
plt.figure(figsize=(12, 10))
correlation_matrix = df[health_columns + pollutant_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Health Indicators and Pollutants')
plt.tight_layout()
plt.show()

# %%
key_pollutants = ['black_carbon', 'nitric_dioxide', 'nitric_oxide', 'nitrogen_oxides_as_nitrogen_dioxide', 'Ozone', 'PM10', 'PM2.5']

# 11. Seasonal Analysis (Monthly Averages)
df['month'] = df['date'].dt.to_period('M')
monthly_avg = df.groupby('month')[health_columns + key_pollutants].mean()

plt.figure(figsize=(12, 6))
for col in health_columns:
    plt.plot(monthly_avg.index.astype(str), monthly_avg[col], label=col, marker='o')
plt.title('Monthly Average of Health Indicators')
plt.xlabel('Month')
plt.ylabel('Average Cases')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))
for col in key_pollutants:
    plt.plot(monthly_avg.index.astype(str), monthly_avg[col], label=col, marker='o')
plt.title('Monthly Average of Key Pollutants')
plt.xlabel('Month')
plt.ylabel('Average Concentration (µg/m³)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Apply 7-day rolling average
window_size = 7
for col in health_columns:
    df[f"{col}_rolling"] = df[col].rolling(window=window_size).mean()

# Plot
plt.figure(figsize=(10, 5))
for col in health_columns:
    plt.plot(df['date'], df[f"{col}_rolling"], label=f"{col} (7-Day Avg)")
plt.title("7-Day Rolling Averages of Health Indicators")
plt.xlabel("Date")
plt.ylabel("Cases")
plt.xticks(rotation=45)
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')   --> Dont ignore labels later
plt.tight_layout()
plt.show()

# Apply 7-day rolling average
window_size = 7
for col in key_pollutants:
    df[f"{col}_rolling"] = df[col].rolling(window=window_size).mean()

# Plot
plt.figure(figsize=(10, 5))
for col in key_pollutants:
    plt.plot(df['date'], df[f"{col}_rolling"], label=f"{col} (7-Day Avg)")
plt.title("7-Day Rolling Averages of Pollutants")
plt.xlabel("Date")
plt.ylabel("Cases")
plt.xticks(rotation=45)
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Seasonal Decomposition of Health Indicators
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Initialize plot grid: 4 rows x 4 columns
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20, 12))
fig.suptitle("Seasonal Decomposition of Health Indicators", fontsize=18)

# Loop through health indicators
for row_idx, col in enumerate(health_columns):
    ts = df[col].dropna()

    # Skip if insufficient data
    if len(ts) < 60:
        print(f"Skipping {col} (not enough data points)")
        continue

    # Decompose the time series
    result = seasonal_decompose(ts, model='additive', period=30)

    # Plot into 4 subplots (Observed, Trend, Seasonal, Residual)
    components = [result.observed, result.trend, result.resid]  #result.seasonal
    titles = ['Observed', 'Trend', 'Residual']

    for col_idx, (component, title) in enumerate(zip(components, titles)):
        ax = axes[row_idx, col_idx]
        component.plot(ax=ax, legend=False)
        ax.set_title(f"{col.replace('_', ' ').title()} - {title}")
        ax.set_xlabel("")
        ax.set_ylabel("")

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Seasonal Decomposition of Key Pollutants
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Initialize plot grid: 4 rows x 4 columns
fig, axes = plt.subplots(nrows=7, ncols=3, figsize=(20, 12))
fig.suptitle("Seasonal Decomposition of Key pollutants", fontsize=18)

# Loop through health indicators
for row_idx, col in enumerate(key_pollutants):
    ts = df[col].dropna()

    # Skip if insufficient data
    if len(ts) < 60:
        print(f"Skipping {col} (not enough data points)")
        continue

    # Decompose the time series
    result = seasonal_decompose(ts, model='additive', period=30)

    # Plot into 4 subplots (Observed, Trend, Seasonal, Residual)
    components = [result.observed, result.trend, result.resid]  #result.seasonal
    titles = ['Observed', 'Trend', 'Residual']

    for col_idx, (component, title) in enumerate(zip(components, titles)):
        ax = axes[row_idx, col_idx]
        component.plot(ax=ax, legend=False)
        ax.set_title(f"{col.replace('_', ' ').title()} - {title}")
        ax.set_xlabel("")
        ax.set_ylabel("")

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ### Lag Analysis

# %%
# Compute cross-correlations for different lags
max_lag = 30
results = []

for illness in health_columns:
    for pollutant in key_pollutants:
        for lag in range(1, max_lag + 1):
            shifted = df[pollutant].shift(lag)
            corr = df[illness].corr(shifted)
            results.append((illness, pollutant, lag, corr))

# Convert to DataFrame
lag_df = pd.DataFrame(results, columns=['illness', 'pollutant', 'lag', 'correlation'])

# Find top positive correlations (pollution precedes illness)
top_lags = lag_df.sort_values(by='correlation', ascending=False).groupby('illness').head()

top_lags
# Out:
#                            illness                            pollutant  lag  \
# 263      acute_respiratory_illness                       nitric_dioxide   24
# 256      acute_respiratory_illness                       nitric_dioxide   17
# 269      acute_respiratory_illness                       nitric_dioxide   30
# 258      acute_respiratory_illness                       nitric_dioxide   19
# 259      acute_respiratory_illness                       nitric_dioxide   20
# 479       influenza_like_syndromic                       nitric_dioxide   30
# 539       influenza_like_syndromic  nitrogen_oxides_as_nitrogen_dioxide   30
# 41   acute_bronchiolitis_syndromic                       nitric_dioxide   12
# 42   acute_bronchiolitis_syndromic                       nitric_dioxide   13
# 478       influenza_like_syndromic                       nitric_dioxide   29
# 509       influenza_like_syndromic                         nitric_oxide   30
# 47   acute_bronchiolitis_syndromic                       nitric_dioxide   18
# 35   acute_bronchiolitis_syndromic                       nitric_dioxide    6
# 34   acute_bronchiolitis_syndromic                       nitric_dioxide    5
# 538       influenza_like_syndromic  nitrogen_oxides_as_nitrogen_dioxide   29
# 744        scarlet_fever_syndromic  nitrogen_oxides_as_nitrogen_dioxide   25
# 809        scarlet_fever_syndromic                                 PM10   30
# 684        scarlet_fever_syndromic                       nitric_dioxide   25
# 806        scarlet_fever_syndromic                                 PM10   27
# 838        scarlet_fever_syndromic                                PM2.5   29
#
#      correlation
# 263     0.369553
# 256     0.366024
# 269     0.365201
# 258     0.364014
# 259     0.361960
# 479     0.359481
# 539     0.350948
# 41      0.330144
# 42      0.327834
# 478     0.319971
# 509     0.318194
# 47      0.314746
# 35      0.314512
# 34      0.312356
# 538     0.308044
# 744     0.145880
# 809     0.144288
# 684     0.139979
# 806     0.139348
# 838     0.139087

# %% [markdown]
# 1. Acute respiratory illness : nitric dioxide : 24 days : 0.370
# 2. Acute respiratory illness : nitric dioxide : 17 days : 0.366
# 3. Acute respiratory illness : nitric dioxide : 30 days : 0.365

# %% [markdown]
# Advanced Lag Modeling (TOP PRIORITY)
# Distributed Lag Models:
# - Implement polynomial distributed lag models
# - Test cumulative exposure windows (7, 14, 21, 30 days)
# - Use Almon lag structures for smooth lag distributions
# - Apply constrained distributed lag models

# %%
from sklearn.preprocessing import MinMaxScaler

#use it on new dataset dont change the original dataset
# Make a copy of the original dataset
df_new = df.copy()

# Feature Engineering Setup
df_new['date'] = pd.to_datetime(df_new['date'], dayfirst=True)
df_new.set_index('date', inplace=True)

# 1. Create 'season' feature
def get_season(date):
    month = date.month
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Autumn'

df_new['season'] = df_new.index.map(get_season)

# 2. Create 'weekday' and 'is_weekend' features
df_new['weekday'] = df_new.index.day_name()
df_new['is_weekend'] = df_new['weekday'].isin(['Saturday', 'Sunday'])

# 3. Create AQI proxy using normalized key pollutants
scaler = MinMaxScaler()
df_new['aqi_proxy'] = scaler.fit_transform(df_new[key_pollutants]).mean(axis=1)

# Weekday vs. Weekend comparison
weekday_summary = df_new.groupby('is_weekend')[
    key_pollutants + [
        'acute_respiratory_illness',
        'influenza_like_syndromic',
        'acute_bronchiolitis_syndromic',
        'scarlet_fever_syndromic'
    ] + ['aqi_proxy'] 
].mean().round(2)

# Preview updated features and summary
#df_new[['season', 'weekday', 'is_weekend', 'aqi_proxy']].head()
weekday_summary
# Out:
#             black_carbon  nitric_dioxide  nitric_oxide  \
# is_weekend
# False               0.97           18.55          8.93
# True                0.86           14.42          6.25
#
#             nitrogen_oxides_as_nitrogen_dioxide  Ozone   PM10  PM2.5  \
# is_weekend
# False                                     32.23  49.91  13.99   8.24
# True                                      23.98  52.29  13.42   8.75
#
#             acute_respiratory_illness  influenza_like_syndromic  \
# is_weekend
# False                          214.43                     10.70
# True                           214.47                     11.28
#
#             acute_bronchiolitis_syndromic  scarlet_fever_syndromic  aqi_proxy
# is_weekend
# False                               14.17                     0.40       0.22
# True                                15.14                     0.75       0.19

# %% [markdown]
# Key Observations:
#
# Weekdays: Higher pollution levels (except ozone and PM2.5)
#
# Weekends: Lower traffic-related pollutants, slightly higher illness rates for some conditions

# %%
import seaborn as sns

# Prepare data
df_new['index'] = range(len(df_new))

# Set style
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))

# Create the line plot
ax = sns.lineplot(data=df_new, x='index', y='aqi_proxy',
                  linewidth=1)

# Add seasonal backgrounds
season_colors = {
    'Spring': '#90EE90',
    'Summer': '#FFE4B5', 
    'Autumn': '#DEB887',
    'Winter': '#B0E0E6'
}

# Group by season and add background
for season in df_new['season'].unique():
    season_data = df_new[df_new['season'] == season]
    if len(season_data) > 1:
        ax.axvspan(season_data['index'].min() - 0.5, 
                   season_data['index'].max() + 0.5,
                   alpha=0.3, color=season_colors.get(season, 'gray'),
                   label=season)

plt.title('AQI Proxy Over Time with Seasonal Areas')
plt.xlabel('Time Points')
plt.ylabel('AQI Proxy')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
